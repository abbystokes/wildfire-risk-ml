# %%
# Code file for pre-processing data: cropping, padding, creating label mask, and saving as tif file in data folder
# Does not save any ignition point or time information (next step)

import numpy as np
import pandas as pd
import os
import rasterio
import geopandas as gpd
from rasterio.warp import reproject, Resampling
from rasterio.windows import Window

# Load metadata and filter for Maule region with fire scar
df = pd.read_excel("FireScar_CL_Summary_1985-2018.xlsx")
df = df[(df['FireScar'] == 1) & (df['Region_CONAF'] == 'Maule')].reset_index(drop=True)

# Output directory
output_dir = "data"
os.makedirs(output_dir, exist_ok=True)

def process_fire_event(fire_id, df):
    example_fire = df.loc[fire_id]
    fire_season = example_fire["FireSeason"]
    folder = f"Fire_CL-ML_Maule/FireScar_CL-ML_Maule_{fire_season}"
    
    # Paths to raster and vector files
    pre_fire_path = os.path.join(folder, example_fire["PreFireImgName"])
    post_fire_path = os.path.join(folder, example_fire["PostFireImgName"])
    fire_scar_vector_path = os.path.join(folder, example_fire["FireScarVectorName"])
    fire_scar_path = os.path.join(folder, example_fire["FireScarImgName"])
    severity_path = os.path.join(folder, example_fire["SeverityImgName"])

    merged_filename = os.path.join(output_dir, f"merged_{fire_id}.tif")
    mask_filename = os.path.join(output_dir, f"mask_{fire_id}.tif")

    # Load ignition point
    fire_scar_vector = gpd.read_file(fire_scar_vector_path).to_crs(epsg=4326)
    target_lat = fire_scar_vector['IgnLat'][0]
    target_lon = fire_scar_vector['IgnLon'][0]

    # Crop and save merged post-fire image
    with rasterio.open(post_fire_path) as src:
        xsize, ysize = 512, 512
        target_x, target_y = src.index(target_lon, target_lat)
        xoff = target_x - xsize // 2
        yoff = target_y - ysize // 2
        window = Window(xoff, yoff, xsize, ysize).round_offsets()
        transform = src.window_transform(window)
        profile = src.profile
        profile.update({
            'height': ysize,
            'width': xsize,
            'transform': transform
        })
        data = src.read(window=window, boundless=True, fill_value=np.nan)
        with rasterio.open(merged_filename, 'w', **profile) as dst:
            dst.write(data)

    # Check dimensions
    with rasterio.open(merged_filename) as check:
        if check.width != 512 or check.height != 512:
            print(f"⚠️ Dimension error for fire {fire_id}")

    # Create fire scar label mask
    with rasterio.open(merged_filename) as cropped_src:
        dst_crs = cropped_src.crs
        dst_transform = cropped_src.transform
        dst_shape = cropped_src.shape
        dst_meta = cropped_src.meta.copy()

    with rasterio.open(fire_scar_path) as fire_src:
        fire_scar_data = fire_src.read(1)
        src_crs = fire_src.crs
        src_transform = fire_src.transform

    resampled_fire_scar = np.zeros(dst_shape, dtype=fire_scar_data.dtype)
    reproject(
        source=fire_scar_data,
        destination=resampled_fire_scar,
        src_transform=src_transform,
        src_crs=src_crs,
        dst_transform=dst_transform,
        dst_crs=dst_crs,
        resampling=Resampling.nearest
    )

    dst_meta.update({
        'height': dst_shape[0],
        'width': dst_shape[1],
        'transform': dst_transform,
        'crs': dst_crs,
        'count': 1,
        'dtype': fire_scar_data.dtype
    })

    with rasterio.open(mask_filename, 'w', **dst_meta) as dst:
        dst.write(resampled_fire_scar, 1)

    print(f"✅ Fire {fire_id} processed and saved to '{output_dir}'")

# Run the loop over all events
for fire_id in range(len(df)):
    try:
        process_fire_event(fire_id, df)
    except Exception as e:
        print(f"❌ Error processing fire {fire_id}: {e}")
# Out:
# ✅ Fire 0 processed and saved to 'data'
# ✅ Fire 1 processed and saved to 'data'
# ✅ Fire 2 processed and saved to 'data'
# ✅ Fire 3 processed and saved to 'data'
# ✅ Fire 4 processed and saved to 'data'
# ✅ Fire 5 processed and saved to 'data'
# ✅ Fire 6 processed and saved to 'data'
# ✅ Fire 7 processed and saved to 'data'
# ✅ Fire 8 processed and saved to 'data'
# ✅ Fire 9 processed and saved to 'data'
# ✅ Fire 10 processed and saved to 'data'
# ✅ Fire 11 processed and saved to 'data'
# ✅ Fire 12 processed and saved to 'data'
# ✅ Fire 13 processed and saved to 'data'
# ✅ Fire 14 processed and saved to 'data'
# ✅ Fire 15 processed and saved to 'data'
# ✅ Fire 16 processed and saved to 'data'
# ✅ Fire 17 processed and saved to 'data'
# ✅ Fire 18 processed and saved to 'data'
# ✅ Fire 19 processed and saved to 'data'
# ✅ Fire 20 processed and saved to 'data'
# ✅ Fire 21 processed and saved to 'data'
# ✅ Fire 22 processed and saved to 'data'
# ✅ Fire 23 processed and saved to 'data'
# ✅ Fire 24 processed and saved to 'data'
# ✅ Fire 25 processed and saved to 'data'
# ✅ Fire 26 processed and saved to 'data'
# ✅ Fire 27 processed and saved to 'data'
# ✅ Fire 28 processed and saved to 'data'
# ✅ Fire 29 processed and saved to 'data'
# ✅ Fire 30 processed and saved to 'data'
# ✅ Fire 31 processed and saved to 'data'
# ✅ Fire 32 processed and saved to 'data'
# ✅ Fire 33 processed and saved to 'data'
# ✅ Fire 34 processed and saved to 'data'
# ✅ Fire 35 processed and saved to 'data'
# ✅ Fire 36 processed and saved to 'data'
# ✅ Fire 37 processed and saved to 'data'
# ✅ Fire 38 processed and saved to 'data'
# ✅ Fire 39 processed and saved to 'data'
# ✅ Fire 40 processed and saved to 'data'
# ✅ Fire 41 processed and saved to 'data'
# ✅ Fire 42 processed and saved to 'data'
# ✅ Fire 43 processed and saved to 'data'
# ✅ Fire 44 processed and saved to 'data'
# ✅ Fire 45 processed and saved to 'data'
# ✅ Fire 46 processed and saved to 'data'
# ✅ Fire 47 processed and saved to 'data'
# ✅ Fire 48 processed and saved to 'data'
# ✅ Fire 49 processed and saved to 'data'
# ✅ Fire 50 processed and saved to 'data'
# ✅ Fire 51 processed and saved to 'data'
# ✅ Fire 52 processed and saved to 'data'
# ✅ Fire 53 processed and saved to 'data'
# ✅ Fire 54 processed and saved to 'data'
# ✅ Fire 55 processed and saved to 'data'
# ✅ Fire 56 processed and saved to 'data'
# ✅ Fire 57 processed and saved to 'data'
# ✅ Fire 58 processed and saved to 'data'
# ✅ Fire 59 processed and saved to 'data'
# ✅ Fire 60 processed and saved to 'data'
# ✅ Fire 61 processed and saved to 'data'
# ✅ Fire 62 processed and saved to 'data'
# ✅ Fire 63 processed and saved to 'data'
# ✅ Fire 64 processed and saved to 'data'
# ✅ Fire 65 processed and saved to 'data'
# ✅ Fire 66 processed and saved to 'data'
# ✅ Fire 67 processed and saved to 'data'
# ✅ Fire 68 processed and saved to 'data'
# ✅ Fire 69 processed and saved to 'data'
# ✅ Fire 70 processed and saved to 'data'
# ✅ Fire 71 processed and saved to 'data'
# ✅ Fire 72 processed and saved to 'data'
# ✅ Fire 73 processed and saved to 'data'
# ✅ Fire 74 processed and saved to 'data'
# ✅ Fire 75 processed and saved to 'data'
# ✅ Fire 76 processed and saved to 'data'
# ✅ Fire 77 processed and saved to 'data'
# ✅ Fire 78 processed and saved to 'data'
# ✅ Fire 79 processed and saved to 'data'
# ✅ Fire 80 processed and saved to 'data'
# ✅ Fire 81 processed and saved to 'data'
# ✅ Fire 82 processed and saved to 'data'
# ✅ Fire 83 processed and saved to 'data'
# ✅ Fire 84 processed and saved to 'data'
# ✅ Fire 85 processed and saved to 'data'
# ✅ Fire 86 processed and saved to 'data'
# ✅ Fire 87 processed and saved to 'data'
# ✅ Fire 88 processed and saved to 'data'
# ✅ Fire 89 processed and saved to 'data'
# ✅ Fire 90 processed and saved to 'data'
# ✅ Fire 91 processed and saved to 'data'
# ✅ Fire 92 processed and saved to 'data'
# ✅ Fire 93 processed and saved to 'data'
# ✅ Fire 94 processed and saved to 'data'
# ✅ Fire 95 processed and saved to 'data'
# ✅ Fire 96 processed and saved to 'data'
# ✅ Fire 97 processed and saved to 'data'
# ✅ Fire 98 processed and saved to 'data'
# ✅ Fire 99 processed and saved to 'data'
# ✅ Fire 100 processed and saved to 'data'
# ✅ Fire 101 processed and saved to 'data'
# ✅ Fire 102 processed and saved to 'data'
# ✅ Fire 103 processed and saved to 'data'
# ✅ Fire 104 processed and saved to 'data'
# ✅ Fire 105 processed and saved to 'data'
# ✅ Fire 106 processed and saved to 'data'
# ✅ Fire 107 processed and saved to 'data'
# ✅ Fire 108 processed and saved to 'data'
# ✅ Fire 109 processed and saved to 'data'
# ✅ Fire 110 processed and saved to 'data'
# ✅ Fire 111 processed and saved to 'data'
# ✅ Fire 112 processed and saved to 'data'
# ✅ Fire 113 processed and saved to 'data'
# ✅ Fire 114 processed and saved to 'data'
# ✅ Fire 115 processed and saved to 'data'
# ✅ Fire 116 processed and saved to 'data'
# ✅ Fire 117 processed and saved to 'data'
# ✅ Fire 118 processed and saved to 'data'
# ✅ Fire 119 processed and saved to 'data'
# ✅ Fire 120 processed and saved to 'data'
# ✅ Fire 121 processed and saved to 'data'
# ✅ Fire 122 processed and saved to 'data'
# ✅ Fire 123 processed and saved to 'data'
# ✅ Fire 124 processed and saved to 'data'
# ✅ Fire 125 processed and saved to 'data'
# ✅ Fire 126 processed and saved to 'data'
# ✅ Fire 127 processed and saved to 'data'
# ✅ Fire 128 processed and saved to 'data'
# ✅ Fire 129 processed and saved to 'data'
# ✅ Fire 130 processed and saved to 'data'
# ✅ Fire 131 processed and saved to 'data'
# ✅ Fire 132 processed and saved to 'data'
# ✅ Fire 133 processed and saved to 'data'
# ✅ Fire 134 processed and saved to 'data'
# ✅ Fire 135 processed and saved to 'data'
# ✅ Fire 136 processed and saved to 'data'
# ✅ Fire 137 processed and saved to 'data'
# ✅ Fire 138 processed and saved to 'data'
# ✅ Fire 139 processed and saved to 'data'
# ✅ Fire 140 processed and saved to 'data'
# ✅ Fire 141 processed and saved to 'data'
# ✅ Fire 142 processed and saved to 'data'
# ✅ Fire 143 processed and saved to 'data'
# ✅ Fire 144 processed and saved to 'data'
# ✅ Fire 145 processed and saved to 'data'
# ✅ Fire 146 processed and saved to 'data'
# ✅ Fire 147 processed and saved to 'data'
# ✅ Fire 148 processed and saved to 'data'
# ✅ Fire 149 processed and saved to 'data'
# ✅ Fire 150 processed and saved to 'data'
# ✅ Fire 151 processed and saved to 'data'
# ✅ Fire 152 processed and saved to 'data'
# ✅ Fire 153 processed and saved to 'data'
# ✅ Fire 154 processed and saved to 'data'
# ✅ Fire 155 processed and saved to 'data'
# ✅ Fire 156 processed and saved to 'data'
# ✅ Fire 157 processed and saved to 'data'
# ✅ Fire 158 processed and saved to 'data'
# ✅ Fire 159 processed and saved to 'data'
# ✅ Fire 160 processed and saved to 'data'
# ✅ Fire 161 processed and saved to 'data'
# ✅ Fire 162 processed and saved to 'data'
# ✅ Fire 163 processed and saved to 'data'
# ✅ Fire 164 processed and saved to 'data'
# ✅ Fire 165 processed and saved to 'data'
# ✅ Fire 166 processed and saved to 'data'
# ✅ Fire 167 processed and saved to 'data'
# ✅ Fire 168 processed and saved to 'data'
# ✅ Fire 169 processed and saved to 'data'
# ✅ Fire 170 processed and saved to 'data'
# ✅ Fire 171 processed and saved to 'data'
# ✅ Fire 172 processed and saved to 'data'
# ✅ Fire 173 processed and saved to 'data'
# ✅ Fire 174 processed and saved to 'data'
# ✅ Fire 175 processed and saved to 'data'
# ✅ Fire 176 processed and saved to 'data'
# ✅ Fire 177 processed and saved to 'data'
# ✅ Fire 178 processed and saved to 'data'
# ✅ Fire 179 processed and saved to 'data'
# ✅ Fire 180 processed and saved to 'data'
# ✅ Fire 181 processed and saved to 'data'
# ✅ Fire 182 processed and saved to 'data'
# ✅ Fire 183 processed and saved to 'data'
# ✅ Fire 184 processed and saved to 'data'
# ✅ Fire 185 processed and saved to 'data'
# ✅ Fire 186 processed and saved to 'data'
# ✅ Fire 187 processed and saved to 'data'
# ✅ Fire 188 processed and saved to 'data'
# ✅ Fire 189 processed and saved to 'data'
# ✅ Fire 190 processed and saved to 'data'
# ✅ Fire 191 processed and saved to 'data'
# ✅ Fire 192 processed and saved to 'data'
# ✅ Fire 193 processed and saved to 'data'
# ✅ Fire 194 processed and saved to 'data'
# ✅ Fire 195 processed and saved to 'data'
# ✅ Fire 196 processed and saved to 'data'
# ✅ Fire 197 processed and saved to 'data'
# ✅ Fire 198 processed and saved to 'data'
# ✅ Fire 199 processed and saved to 'data'
# ✅ Fire 200 processed and saved to 'data'
# ✅ Fire 201 processed and saved to 'data'
# ✅ Fire 202 processed and saved to 'data'
# ✅ Fire 203 processed and saved to 'data'
# ✅ Fire 204 processed and saved to 'data'
# ✅ Fire 205 processed and saved to 'data'
# ✅ Fire 206 processed and saved to 'data'
# ✅ Fire 207 processed and saved to 'data'
# ✅ Fire 208 processed and saved to 'data'
# ✅ Fire 209 processed and saved to 'data'
# ✅ Fire 210 processed and saved to 'data'
# ✅ Fire 211 processed and saved to 'data'
# ✅ Fire 212 processed and saved to 'data'
# ✅ Fire 213 processed and saved to 'data'
# ✅ Fire 214 processed and saved to 'data'
# ✅ Fire 215 processed and saved to 'data'
# ✅ Fire 216 processed and saved to 'data'
# ✅ Fire 217 processed and saved to 'data'
# ✅ Fire 218 processed and saved to 'data'
# ✅ Fire 219 processed and saved to 'data'
# ✅ Fire 220 processed and saved to 'data'
# ✅ Fire 221 processed and saved to 'data'
# ✅ Fire 222 processed and saved to 'data'
# ✅ Fire 223 processed and saved to 'data'
# ✅ Fire 224 processed and saved to 'data'
# ✅ Fire 225 processed and saved to 'data'
# ✅ Fire 226 processed and saved to 'data'
# ✅ Fire 227 processed and saved to 'data'
# ✅ Fire 228 processed and saved to 'data'
# ✅ Fire 229 processed and saved to 'data'
# ✅ Fire 230 processed and saved to 'data'
# ✅ Fire 231 processed and saved to 'data'
# ✅ Fire 232 processed and saved to 'data'
# ✅ Fire 233 processed and saved to 'data'
# ✅ Fire 234 processed and saved to 'data'
# ✅ Fire 235 processed and saved to 'data'
# ✅ Fire 236 processed and saved to 'data'
# ✅ Fire 237 processed and saved to 'data'
# ✅ Fire 238 processed and saved to 'data'
# ✅ Fire 239 processed and saved to 'data'
# ✅ Fire 240 processed and saved to 'data'
# ✅ Fire 241 processed and saved to 'data'
# ✅ Fire 242 processed and saved to 'data'
# ✅ Fire 243 processed and saved to 'data'
# ✅ Fire 244 processed and saved to 'data'
# ✅ Fire 245 processed and saved to 'data'
# ✅ Fire 246 processed and saved to 'data'
# ✅ Fire 247 processed and saved to 'data'
# ✅ Fire 248 processed and saved to 'data'
# ✅ Fire 249 processed and saved to 'data'
# ✅ Fire 250 processed and saved to 'data'
# ✅ Fire 251 processed and saved to 'data'
# ✅ Fire 252 processed and saved to 'data'
# ✅ Fire 253 processed and saved to 'data'
# ✅ Fire 254 processed and saved to 'data'
# ✅ Fire 255 processed and saved to 'data'
# ✅ Fire 256 processed and saved to 'data'
# ✅ Fire 257 processed and saved to 'data'
# ✅ Fire 258 processed and saved to 'data'
# ✅ Fire 259 processed and saved to 'data'
# ✅ Fire 260 processed and saved to 'data'
# ✅ Fire 261 processed and saved to 'data'
# ✅ Fire 262 processed and saved to 'data'
# ✅ Fire 263 processed and saved to 'data'
# ✅ Fire 264 processed and saved to 'data'
# ✅ Fire 265 processed and saved to 'data'
# ✅ Fire 266 processed and saved to 'data'
# ✅ Fire 267 processed and saved to 'data'
# ✅ Fire 268 processed and saved to 'data'
# ✅ Fire 269 processed and saved to 'data'
# ✅ Fire 270 processed and saved to 'data'
# ✅ Fire 271 processed and saved to 'data'
# ✅ Fire 272 processed and saved to 'data'
# ✅ Fire 273 processed and saved to 'data'
# ✅ Fire 274 processed and saved to 'data'
# ✅ Fire 275 processed and saved to 'data'
# ✅ Fire 276 processed and saved to 'data'
# ✅ Fire 277 processed and saved to 'data'
# ✅ Fire 278 processed and saved to 'data'
# ✅ Fire 279 processed and saved to 'data'
# ✅ Fire 280 processed and saved to 'data'
# ✅ Fire 281 processed and saved to 'data'
# ✅ Fire 282 processed and saved to 'data'
# ✅ Fire 283 processed and saved to 'data'
# ✅ Fire 284 processed and saved to 'data'
# ✅ Fire 285 processed and saved to 'data'
# ✅ Fire 286 processed and saved to 'data'
# ✅ Fire 287 processed and saved to 'data'
# ✅ Fire 288 processed and saved to 'data'
# ✅ Fire 289 processed and saved to 'data'
# ✅ Fire 290 processed and saved to 'data'
# ✅ Fire 291 processed and saved to 'data'
# ✅ Fire 292 processed and saved to 'data'
# ✅ Fire 293 processed and saved to 'data'
# ✅ Fire 294 processed and saved to 'data'
# ✅ Fire 295 processed and saved to 'data'
# ✅ Fire 296 processed and saved to 'data'
# ✅ Fire 297 processed and saved to 'data'
# ✅ Fire 298 processed and saved to 'data'
# ✅ Fire 299 processed and saved to 'data'
# ✅ Fire 300 processed and saved to 'data'
# ✅ Fire 301 processed and saved to 'data'
# ✅ Fire 302 processed and saved to 'data'
# ✅ Fire 303 processed and saved to 'data'
# ✅ Fire 304 processed and saved to 'data'
# ✅ Fire 305 processed and saved to 'data'
# ✅ Fire 306 processed and saved to 'data'
# ✅ Fire 307 processed and saved to 'data'
# ✅ Fire 308 processed and saved to 'data'
# ✅ Fire 309 processed and saved to 'data'
# ✅ Fire 310 processed and saved to 'data'
# ✅ Fire 311 processed and saved to 'data'
# ✅ Fire 312 processed and saved to 'data'
# ✅ Fire 313 processed and saved to 'data'
# ✅ Fire 314 processed and saved to 'data'
# ✅ Fire 315 processed and saved to 'data'
# ✅ Fire 316 processed and saved to 'data'
# ✅ Fire 317 processed and saved to 'data'
# ✅ Fire 318 processed and saved to 'data'
# ✅ Fire 319 processed and saved to 'data'
# ✅ Fire 320 processed and saved to 'data'
# ✅ Fire 321 processed and saved to 'data'
# ✅ Fire 322 processed and saved to 'data'
# ✅ Fire 323 processed and saved to 'data'
# ✅ Fire 324 processed and saved to 'data'
# ✅ Fire 325 processed and saved to 'data'
# ✅ Fire 326 processed and saved to 'data'
# ✅ Fire 327 processed and saved to 'data'
# ✅ Fire 328 processed and saved to 'data'
# ✅ Fire 329 processed and saved to 'data'
# ✅ Fire 330 processed and saved to 'data'
# ✅ Fire 331 processed and saved to 'data'
# ✅ Fire 332 processed and saved to 'data'
# ✅ Fire 333 processed and saved to 'data'
# ✅ Fire 334 processed and saved to 'data'
# ✅ Fire 335 processed and saved to 'data'
# ✅ Fire 336 processed and saved to 'data'
# ✅ Fire 337 processed and saved to 'data'
# ✅ Fire 338 processed and saved to 'data'
# ✅ Fire 339 processed and saved to 'data'
# ✅ Fire 340 processed and saved to 'data'
# ✅ Fire 341 processed and saved to 'data'
# ✅ Fire 342 processed and saved to 'data'
# ✅ Fire 343 processed and saved to 'data'
# ✅ Fire 344 processed and saved to 'data'
# ✅ Fire 345 processed and saved to 'data'
# ✅ Fire 346 processed and saved to 'data'
# ✅ Fire 347 processed and saved to 'data'
# ✅ Fire 348 processed and saved to 'data'
# ✅ Fire 349 processed and saved to 'data'
# ✅ Fire 350 processed and saved to 'data'
# ✅ Fire 351 processed and saved to 'data'
# ✅ Fire 352 processed and saved to 'data'
# ✅ Fire 353 processed and saved to 'data'
# ✅ Fire 354 processed and saved to 'data'
# ✅ Fire 355 processed and saved to 'data'
# ✅ Fire 356 processed and saved to 'data'
# ✅ Fire 357 processed and saved to 'data'
# ✅ Fire 358 processed and saved to 'data'
# ✅ Fire 359 processed and saved to 'data'
# ✅ Fire 360 processed and saved to 'data'
# ✅ Fire 361 processed and saved to 'data'
# ✅ Fire 362 processed and saved to 'data'
# ✅ Fire 363 processed and saved to 'data'
# ✅ Fire 364 processed and saved to 'data'
# ✅ Fire 365 processed and saved to 'data'
# ✅ Fire 366 processed and saved to 'data'
# ✅ Fire 367 processed and saved to 'data'
# ✅ Fire 368 processed and saved to 'data'
# ✅ Fire 369 processed and saved to 'data'
# ✅ Fire 370 processed and saved to 'data'
# ✅ Fire 371 processed and saved to 'data'
# ✅ Fire 372 processed and saved to 'data'
# ✅ Fire 373 processed and saved to 'data'
# ✅ Fire 374 processed and saved to 'data'
# ✅ Fire 375 processed and saved to 'data'
# ✅ Fire 376 processed and saved to 'data'
# ✅ Fire 377 processed and saved to 'data'
# ✅ Fire 378 processed and saved to 'data'
# ✅ Fire 379 processed and saved to 'data'
# ✅ Fire 380 processed and saved to 'data'
# ✅ Fire 381 processed and saved to 'data'
# ✅ Fire 382 processed and saved to 'data'
# ✅ Fire 383 processed and saved to 'data'
# ✅ Fire 384 processed and saved to 'data'
# ✅ Fire 385 processed and saved to 'data'
# ✅ Fire 386 processed and saved to 'data'
# ✅ Fire 387 processed and saved to 'data'
# ✅ Fire 388 processed and saved to 'data'
# ✅ Fire 389 processed and saved to 'data'
# ✅ Fire 390 processed and saved to 'data'
# ✅ Fire 391 processed and saved to 'data'
# ✅ Fire 392 processed and saved to 'data'
# ✅ Fire 393 processed and saved to 'data'
# ✅ Fire 394 processed and saved to 'data'
# ✅ Fire 395 processed and saved to 'data'
# ✅ Fire 396 processed and saved to 'data'
# ✅ Fire 397 processed and saved to 'data'
# ✅ Fire 398 processed and saved to 'data'
# ✅ Fire 399 processed and saved to 'data'
# ✅ Fire 400 processed and saved to 'data'
# ✅ Fire 401 processed and saved to 'data'
# ✅ Fire 402 processed and saved to 'data'
# ✅ Fire 403 processed and saved to 'data'
# ✅ Fire 404 processed and saved to 'data'
# ✅ Fire 405 processed and saved to 'data'
# ✅ Fire 406 processed and saved to 'data'
# ✅ Fire 407 processed and saved to 'data'
# ✅ Fire 408 processed and saved to 'data'
# ✅ Fire 409 processed and saved to 'data'
# ✅ Fire 410 processed and saved to 'data'
# ✅ Fire 411 processed and saved to 'data'
# ✅ Fire 412 processed and saved to 'data'
# ✅ Fire 413 processed and saved to 'data'
# ✅ Fire 414 processed and saved to 'data'
# ✅ Fire 415 processed and saved to 'data'
# ✅ Fire 416 processed and saved to 'data'
# ✅ Fire 417 processed and saved to 'data'
# ✅ Fire 418 processed and saved to 'data'
# ✅ Fire 419 processed and saved to 'data'
# ✅ Fire 420 processed and saved to 'data'
# ✅ Fire 421 processed and saved to 'data'
# ✅ Fire 422 processed and saved to 'data'
# ✅ Fire 423 processed and saved to 'data'
# ✅ Fire 424 processed and saved to 'data'
# ✅ Fire 425 processed and saved to 'data'
# ✅ Fire 426 processed and saved to 'data'
# ✅ Fire 427 processed and saved to 'data'
# ✅ Fire 428 processed and saved to 'data'
# ✅ Fire 429 processed and saved to 'data'
# ✅ Fire 430 processed and saved to 'data'
# ✅ Fire 431 processed and saved to 'data'
# ✅ Fire 432 processed and saved to 'data'
# ✅ Fire 433 processed and saved to 'data'
# ✅ Fire 434 processed and saved to 'data'
# ✅ Fire 435 processed and saved to 'data'
# ✅ Fire 436 processed and saved to 'data'
# ✅ Fire 437 processed and saved to 'data'
# ✅ Fire 438 processed and saved to 'data'
# ✅ Fire 439 processed and saved to 'data'
# ✅ Fire 440 processed and saved to 'data'
# ✅ Fire 441 processed and saved to 'data'
# ✅ Fire 442 processed and saved to 'data'
# ✅ Fire 443 processed and saved to 'data'
# ✅ Fire 444 processed and saved to 'data'
# ✅ Fire 445 processed and saved to 'data'
# ✅ Fire 446 processed and saved to 'data'
# ✅ Fire 447 processed and saved to 'data'
# ✅ Fire 448 processed and saved to 'data'
# ✅ Fire 449 processed and saved to 'data'
# ✅ Fire 450 processed and saved to 'data'
# ✅ Fire 451 processed and saved to 'data'
# ✅ Fire 452 processed and saved to 'data'
# ✅ Fire 453 processed and saved to 'data'
# ✅ Fire 454 processed and saved to 'data'
# ✅ Fire 455 processed and saved to 'data'
# ✅ Fire 456 processed and saved to 'data'
# ✅ Fire 457 processed and saved to 'data'
# ✅ Fire 458 processed and saved to 'data'
# ✅ Fire 459 processed and saved to 'data'
# ✅ Fire 460 processed and saved to 'data'
# ✅ Fire 461 processed and saved to 'data'
# ✅ Fire 462 processed and saved to 'data'
# ✅ Fire 463 processed and saved to 'data'
# ✅ Fire 464 processed and saved to 'data'
# ✅ Fire 465 processed and saved to 'data'
# ✅ Fire 466 processed and saved to 'data'
# ✅ Fire 467 processed and saved to 'data'
# ✅ Fire 468 processed and saved to 'data'
# ✅ Fire 469 processed and saved to 'data'
# ✅ Fire 470 processed and saved to 'data'
# ✅ Fire 471 processed and saved to 'data'
# ✅ Fire 472 processed and saved to 'data'
# ✅ Fire 473 processed and saved to 'data'
# ✅ Fire 474 processed and saved to 'data'
# ✅ Fire 475 processed and saved to 'data'
# ✅ Fire 476 processed and saved to 'data'
# ✅ Fire 477 processed and saved to 'data'
# ✅ Fire 478 processed and saved to 'data'
# ✅ Fire 479 processed and saved to 'data'
# ✅ Fire 480 processed and saved to 'data'
# ✅ Fire 481 processed and saved to 'data'
# ✅ Fire 482 processed and saved to 'data'
# ✅ Fire 483 processed and saved to 'data'
# ✅ Fire 484 processed and saved to 'data'
# ✅ Fire 485 processed and saved to 'data'
# ✅ Fire 486 processed and saved to 'data'
# ✅ Fire 487 processed and saved to 'data'
# ✅ Fire 488 processed and saved to 'data'
# ✅ Fire 489 processed and saved to 'data'
# ✅ Fire 490 processed and saved to 'data'
# ✅ Fire 491 processed and saved to 'data'
# ✅ Fire 492 processed and saved to 'data'
# ✅ Fire 493 processed and saved to 'data'
# ✅ Fire 494 processed and saved to 'data'
# ✅ Fire 495 processed and saved to 'data'
# ✅ Fire 496 processed and saved to 'data'
# ✅ Fire 497 processed and saved to 'data'
# ✅ Fire 498 processed and saved to 'data'
# ✅ Fire 499 processed and saved to 'data'
# ✅ Fire 500 processed and saved to 'data'
# ✅ Fire 501 processed and saved to 'data'
# ✅ Fire 502 processed and saved to 'data'
# ✅ Fire 503 processed and saved to 'data'
# ✅ Fire 504 processed and saved to 'data'
# ✅ Fire 505 processed and saved to 'data'
# ✅ Fire 506 processed and saved to 'data'
# ✅ Fire 507 processed and saved to 'data'
# ✅ Fire 508 processed and saved to 'data'
# ✅ Fire 509 processed and saved to 'data'
# ✅ Fire 510 processed and saved to 'data'
# ✅ Fire 511 processed and saved to 'data'
# ✅ Fire 512 processed and saved to 'data'
# ✅ Fire 513 processed and saved to 'data'
# ✅ Fire 514 processed and saved to 'data'
# ✅ Fire 515 processed and saved to 'data'
# ✅ Fire 516 processed and saved to 'data'
# ✅ Fire 517 processed and saved to 'data'
# ✅ Fire 518 processed and saved to 'data'
# ✅ Fire 519 processed and saved to 'data'
# ✅ Fire 520 processed and saved to 'data'
# ✅ Fire 521 processed and saved to 'data'
# ✅ Fire 522 processed and saved to 'data'
# ✅ Fire 523 processed and saved to 'data'
# ✅ Fire 524 processed and saved to 'data'
# ✅ Fire 525 processed and saved to 'data'
# ✅ Fire 526 processed and saved to 'data'
# ✅ Fire 527 processed and saved to 'data'
# ✅ Fire 528 processed and saved to 'data'
# ✅ Fire 529 processed and saved to 'data'
# ✅ Fire 530 processed and saved to 'data'
# ✅ Fire 531 processed and saved to 'data'
# ✅ Fire 532 processed and saved to 'data'
# ✅ Fire 533 processed and saved to 'data'
# ✅ Fire 534 processed and saved to 'data'
# ✅ Fire 535 processed and saved to 'data'
# ✅ Fire 536 processed and saved to 'data'
# ✅ Fire 537 processed and saved to 'data'
# ✅ Fire 538 processed and saved to 'data'
# ✅ Fire 539 processed and saved to 'data'
# ✅ Fire 540 processed and saved to 'data'
# ✅ Fire 541 processed and saved to 'data'
# ✅ Fire 542 processed and saved to 'data'
# ✅ Fire 543 processed and saved to 'data'
# ✅ Fire 544 processed and saved to 'data'
# ✅ Fire 545 processed and saved to 'data'
# ✅ Fire 546 processed and saved to 'data'
# ✅ Fire 547 processed and saved to 'data'
# ✅ Fire 548 processed and saved to 'data'
# ✅ Fire 549 processed and saved to 'data'
# ✅ Fire 550 processed and saved to 'data'
# ✅ Fire 551 processed and saved to 'data'
# ✅ Fire 552 processed and saved to 'data'
# ✅ Fire 553 processed and saved to 'data'
# ✅ Fire 554 processed and saved to 'data'
# ✅ Fire 555 processed and saved to 'data'
# ✅ Fire 556 processed and saved to 'data'
# ✅ Fire 557 processed and saved to 'data'
# ✅ Fire 558 processed and saved to 'data'
# ✅ Fire 559 processed and saved to 'data'
# ✅ Fire 560 processed and saved to 'data'
# ✅ Fire 561 processed and saved to 'data'
# ✅ Fire 562 processed and saved to 'data'
# ✅ Fire 563 processed and saved to 'data'
# ✅ Fire 564 processed and saved to 'data'
# ✅ Fire 565 processed and saved to 'data'
# ✅ Fire 566 processed and saved to 'data'
# ✅ Fire 567 processed and saved to 'data'
# ✅ Fire 568 processed and saved to 'data'
# ✅ Fire 569 processed and saved to 'data'
# ✅ Fire 570 processed and saved to 'data'
# ✅ Fire 571 processed and saved to 'data'
# ✅ Fire 572 processed and saved to 'data'
# ✅ Fire 573 processed and saved to 'data'
# ✅ Fire 574 processed and saved to 'data'
# ✅ Fire 575 processed and saved to 'data'
# ✅ Fire 576 processed and saved to 'data'
# ✅ Fire 577 processed and saved to 'data'
# ✅ Fire 578 processed and saved to 'data'
# ✅ Fire 579 processed and saved to 'data'
# ✅ Fire 580 processed and saved to 'data'
# ✅ Fire 581 processed and saved to 'data'
# ✅ Fire 582 processed and saved to 'data'
# ✅ Fire 583 processed and saved to 'data'
# ✅ Fire 584 processed and saved to 'data'
# ✅ Fire 585 processed and saved to 'data'
# ✅ Fire 586 processed and saved to 'data'
# ✅ Fire 587 processed and saved to 'data'
# ✅ Fire 588 processed and saved to 'data'
# ✅ Fire 589 processed and saved to 'data'
# ✅ Fire 590 processed and saved to 'data'
# ✅ Fire 591 processed and saved to 'data'
# ✅ Fire 592 processed and saved to 'data'
# ✅ Fire 593 processed and saved to 'data'
# ✅ Fire 594 processed and saved to 'data'
# ✅ Fire 595 processed and saved to 'data'
# ✅ Fire 596 processed and saved to 'data'
# ✅ Fire 597 processed and saved to 'data'
# ✅ Fire 598 processed and saved to 'data'
# ✅ Fire 599 processed and saved to 'data'
# ✅ Fire 600 processed and saved to 'data'
# ✅ Fire 601 processed and saved to 'data'
# ✅ Fire 602 processed and saved to 'data'
# ✅ Fire 603 processed and saved to 'data'
# ✅ Fire 604 processed and saved to 'data'
# ✅ Fire 605 processed and saved to 'data'
# ✅ Fire 606 processed and saved to 'data'
# ✅ Fire 607 processed and saved to 'data'
# ✅ Fire 608 processed and saved to 'data'
# ✅ Fire 609 processed and saved to 'data'
# ✅ Fire 610 processed and saved to 'data'
# ✅ Fire 611 processed and saved to 'data'
# ✅ Fire 612 processed and saved to 'data'
# ✅ Fire 613 processed and saved to 'data'
# ✅ Fire 614 processed and saved to 'data'
# ✅ Fire 615 processed and saved to 'data'
# ✅ Fire 616 processed and saved to 'data'
# ✅ Fire 617 processed and saved to 'data'
# ✅ Fire 618 processed and saved to 'data'
# ✅ Fire 619 processed and saved to 'data'
# ✅ Fire 620 processed and saved to 'data'
# ✅ Fire 621 processed and saved to 'data'
# ✅ Fire 622 processed and saved to 'data'
# ✅ Fire 623 processed and saved to 'data'
# ✅ Fire 624 processed and saved to 'data'
# ✅ Fire 625 processed and saved to 'data'
# ✅ Fire 626 processed and saved to 'data'
# ✅ Fire 627 processed and saved to 'data'
# ✅ Fire 628 processed and saved to 'data'
# ✅ Fire 629 processed and saved to 'data'
# ✅ Fire 630 processed and saved to 'data'
# ✅ Fire 631 processed and saved to 'data'
# ✅ Fire 632 processed and saved to 'data'
# ✅ Fire 633 processed and saved to 'data'
# ✅ Fire 634 processed and saved to 'data'
# ✅ Fire 635 processed and saved to 'data'
# ✅ Fire 636 processed and saved to 'data'
# ✅ Fire 637 processed and saved to 'data'
# ✅ Fire 638 processed and saved to 'data'
# ✅ Fire 639 processed and saved to 'data'
# ✅ Fire 640 processed and saved to 'data'
# ✅ Fire 641 processed and saved to 'data'
# ✅ Fire 642 processed and saved to 'data'
# ✅ Fire 643 processed and saved to 'data'
# ✅ Fire 644 processed and saved to 'data'
# ✅ Fire 645 processed and saved to 'data'
# ✅ Fire 646 processed and saved to 'data'
# ✅ Fire 647 processed and saved to 'data'
# ✅ Fire 648 processed and saved to 'data'
# ✅ Fire 649 processed and saved to 'data'
# ✅ Fire 650 processed and saved to 'data'
# ✅ Fire 651 processed and saved to 'data'
# ✅ Fire 652 processed and saved to 'data'
# ✅ Fire 653 processed and saved to 'data'
# ✅ Fire 654 processed and saved to 'data'
# ✅ Fire 655 processed and saved to 'data'
# ✅ Fire 656 processed and saved to 'data'
# ✅ Fire 657 processed and saved to 'data'
# ✅ Fire 658 processed and saved to 'data'
# ✅ Fire 659 processed and saved to 'data'
# ✅ Fire 660 processed and saved to 'data'
# ✅ Fire 661 processed and saved to 'data'
# ✅ Fire 662 processed and saved to 'data'
# ✅ Fire 663 processed and saved to 'data'
# ✅ Fire 664 processed and saved to 'data'
# ✅ Fire 665 processed and saved to 'data'
# ✅ Fire 666 processed and saved to 'data'
# ✅ Fire 667 processed and saved to 'data'
# ✅ Fire 668 processed and saved to 'data'
# ✅ Fire 669 processed and saved to 'data'
# ✅ Fire 670 processed and saved to 'data'
# ✅ Fire 671 processed and saved to 'data'
# ✅ Fire 672 processed and saved to 'data'
# ✅ Fire 673 processed and saved to 'data'
# ✅ Fire 674 processed and saved to 'data'
# ✅ Fire 675 processed and saved to 'data'
# ✅ Fire 676 processed and saved to 'data'
# ✅ Fire 677 processed and saved to 'data'
# ✅ Fire 678 processed and saved to 'data'
# ✅ Fire 679 processed and saved to 'data'
# ✅ Fire 680 processed and saved to 'data'
# ✅ Fire 681 processed and saved to 'data'
# ✅ Fire 682 processed and saved to 'data'
# ✅ Fire 683 processed and saved to 'data'
# ✅ Fire 684 processed and saved to 'data'
# ✅ Fire 685 processed and saved to 'data'
# ✅ Fire 686 processed and saved to 'data'
# ✅ Fire 687 processed and saved to 'data'
# ✅ Fire 688 processed and saved to 'data'
# ✅ Fire 689 processed and saved to 'data'
# ✅ Fire 690 processed and saved to 'data'
# ✅ Fire 691 processed and saved to 'data'
# ✅ Fire 692 processed and saved to 'data'
# ✅ Fire 693 processed and saved to 'data'
# ✅ Fire 694 processed and saved to 'data'
# ✅ Fire 695 processed and saved to 'data'
# ✅ Fire 696 processed and saved to 'data'
# ✅ Fire 697 processed and saved to 'data'
# ✅ Fire 698 processed and saved to 'data'
# ✅ Fire 699 processed and saved to 'data'
# ✅ Fire 700 processed and saved to 'data'
# ✅ Fire 701 processed and saved to 'data'
# ✅ Fire 702 processed and saved to 'data'
# ✅ Fire 703 processed and saved to 'data'
# ✅ Fire 704 processed and saved to 'data'
# ✅ Fire 705 processed and saved to 'data'
# ✅ Fire 706 processed and saved to 'data'
# ✅ Fire 707 processed and saved to 'data'
# ✅ Fire 708 processed and saved to 'data'
# ✅ Fire 709 processed and saved to 'data'
# ✅ Fire 710 processed and saved to 'data'
# ✅ Fire 711 processed and saved to 'data'
# ✅ Fire 712 processed and saved to 'data'
# ✅ Fire 713 processed and saved to 'data'
# ✅ Fire 714 processed and saved to 'data'
# ✅ Fire 715 processed and saved to 'data'
# ✅ Fire 716 processed and saved to 'data'
# ✅ Fire 717 processed and saved to 'data'
# ✅ Fire 718 processed and saved to 'data'
# ✅ Fire 719 processed and saved to 'data'
# ✅ Fire 720 processed and saved to 'data'
# ✅ Fire 721 processed and saved to 'data'
# ✅ Fire 722 processed and saved to 'data'
# ✅ Fire 723 processed and saved to 'data'
# ✅ Fire 724 processed and saved to 'data'
# ✅ Fire 725 processed and saved to 'data'
# ✅ Fire 726 processed and saved to 'data'
# ✅ Fire 727 processed and saved to 'data'
# ✅ Fire 728 processed and saved to 'data'
# ✅ Fire 729 processed and saved to 'data'
# ✅ Fire 730 processed and saved to 'data'
# ✅ Fire 731 processed and saved to 'data'
# ✅ Fire 732 processed and saved to 'data'
# ✅ Fire 733 processed and saved to 'data'
# ✅ Fire 734 processed and saved to 'data'
# ✅ Fire 735 processed and saved to 'data'
# ✅ Fire 736 processed and saved to 'data'
# ✅ Fire 737 processed and saved to 'data'
# ✅ Fire 738 processed and saved to 'data'
# ✅ Fire 739 processed and saved to 'data'
# ✅ Fire 740 processed and saved to 'data'
# ✅ Fire 741 processed and saved to 'data'
# ✅ Fire 742 processed and saved to 'data'
# ✅ Fire 743 processed and saved to 'data'
# ✅ Fire 744 processed and saved to 'data'
# ✅ Fire 745 processed and saved to 'data'
# ✅ Fire 746 processed and saved to 'data'
# ✅ Fire 747 processed and saved to 'data'
# ✅ Fire 748 processed and saved to 'data'
# ✅ Fire 749 processed and saved to 'data'
# ✅ Fire 750 processed and saved to 'data'
# ✅ Fire 751 processed and saved to 'data'
# ✅ Fire 752 processed and saved to 'data'
# ✅ Fire 753 processed and saved to 'data'
# ✅ Fire 754 processed and saved to 'data'
# ✅ Fire 755 processed and saved to 'data'
# ✅ Fire 756 processed and saved to 'data'
# ✅ Fire 757 processed and saved to 'data'
# ✅ Fire 758 processed and saved to 'data'
# ✅ Fire 759 processed and saved to 'data'
# ✅ Fire 760 processed and saved to 'data'
# ✅ Fire 761 processed and saved to 'data'
# ✅ Fire 762 processed and saved to 'data'
# ✅ Fire 763 processed and saved to 'data'
# ✅ Fire 764 processed and saved to 'data'
# ✅ Fire 765 processed and saved to 'data'
# ✅ Fire 766 processed and saved to 'data'
# ✅ Fire 767 processed and saved to 'data'
# ✅ Fire 768 processed and saved to 'data'
# ✅ Fire 769 processed and saved to 'data'
# ✅ Fire 770 processed and saved to 'data'
# ✅ Fire 771 processed and saved to 'data'
# ✅ Fire 772 processed and saved to 'data'
# ✅ Fire 773 processed and saved to 'data'
# ✅ Fire 774 processed and saved to 'data'
# ✅ Fire 775 processed and saved to 'data'
# ✅ Fire 776 processed and saved to 'data'
# ✅ Fire 777 processed and saved to 'data'
# ✅ Fire 778 processed and saved to 'data'
# ✅ Fire 779 processed and saved to 'data'
# ✅ Fire 780 processed and saved to 'data'
# ✅ Fire 781 processed and saved to 'data'
# ✅ Fire 782 processed and saved to 'data'
# ✅ Fire 783 processed and saved to 'data'
# ✅ Fire 784 processed and saved to 'data'
# ✅ Fire 785 processed and saved to 'data'
# ✅ Fire 786 processed and saved to 'data'
# ✅ Fire 787 processed and saved to 'data'
# ✅ Fire 788 processed and saved to 'data'
# ✅ Fire 789 processed and saved to 'data'
# ✅ Fire 790 processed and saved to 'data'
# ✅ Fire 791 processed and saved to 'data'
# ✅ Fire 792 processed and saved to 'data'
# ✅ Fire 793 processed and saved to 'data'
# ✅ Fire 794 processed and saved to 'data'
# ✅ Fire 795 processed and saved to 'data'
# ✅ Fire 796 processed and saved to 'data'
# ✅ Fire 797 processed and saved to 'data'
# ✅ Fire 798 processed and saved to 'data'
# ✅ Fire 799 processed and saved to 'data'
# ✅ Fire 800 processed and saved to 'data'
# ✅ Fire 801 processed and saved to 'data'
# ✅ Fire 802 processed and saved to 'data'
# ✅ Fire 803 processed and saved to 'data'
# ✅ Fire 804 processed and saved to 'data'
# ✅ Fire 805 processed and saved to 'data'
# ✅ Fire 806 processed and saved to 'data'
# ✅ Fire 807 processed and saved to 'data'
# ✅ Fire 808 processed and saved to 'data'
# ✅ Fire 809 processed and saved to 'data'
# ✅ Fire 810 processed and saved to 'data'
# ✅ Fire 811 processed and saved to 'data'
# ✅ Fire 812 processed and saved to 'data'
# ✅ Fire 813 processed and saved to 'data'
# ✅ Fire 814 processed and saved to 'data'
# ✅ Fire 815 processed and saved to 'data'
# ✅ Fire 816 processed and saved to 'data'
# ✅ Fire 817 processed and saved to 'data'
# ✅ Fire 818 processed and saved to 'data'
# ✅ Fire 819 processed and saved to 'data'
# ✅ Fire 820 processed and saved to 'data'
# ✅ Fire 821 processed and saved to 'data'
# ✅ Fire 822 processed and saved to 'data'
# ✅ Fire 823 processed and saved to 'data'
# ✅ Fire 824 processed and saved to 'data'
# ✅ Fire 825 processed and saved to 'data'
# ✅ Fire 826 processed and saved to 'data'
# ✅ Fire 827 processed and saved to 'data'
# ✅ Fire 828 processed and saved to 'data'
# ✅ Fire 829 processed and saved to 'data'
# ✅ Fire 830 processed and saved to 'data'
# ✅ Fire 831 processed and saved to 'data'
# ✅ Fire 832 processed and saved to 'data'
# ✅ Fire 833 processed and saved to 'data'
# ✅ Fire 834 processed and saved to 'data'
# ✅ Fire 835 processed and saved to 'data'
# ✅ Fire 836 processed and saved to 'data'
# ✅ Fire 837 processed and saved to 'data'
# ✅ Fire 838 processed and saved to 'data'
# ✅ Fire 839 processed and saved to 'data'
# ✅ Fire 840 processed and saved to 'data'
# ✅ Fire 841 processed and saved to 'data'
# ✅ Fire 842 processed and saved to 'data'
# ✅ Fire 843 processed and saved to 'data'
# ✅ Fire 844 processed and saved to 'data'
# ✅ Fire 845 processed and saved to 'data'
# ✅ Fire 846 processed and saved to 'data'
# ✅ Fire 847 processed and saved to 'data'
# ✅ Fire 848 processed and saved to 'data'
# ✅ Fire 849 processed and saved to 'data'
# ✅ Fire 850 processed and saved to 'data'
# ✅ Fire 851 processed and saved to 'data'
# ✅ Fire 852 processed and saved to 'data'
# ✅ Fire 853 processed and saved to 'data'
# ✅ Fire 854 processed and saved to 'data'
# ✅ Fire 855 processed and saved to 'data'
# ✅ Fire 856 processed and saved to 'data'
# ✅ Fire 857 processed and saved to 'data'
# ✅ Fire 858 processed and saved to 'data'
# ✅ Fire 859 processed and saved to 'data'
# ✅ Fire 860 processed and saved to 'data'
# ✅ Fire 861 processed and saved to 'data'
# ✅ Fire 862 processed and saved to 'data'
# ✅ Fire 863 processed and saved to 'data'
# ✅ Fire 864 processed and saved to 'data'
# ✅ Fire 865 processed and saved to 'data'
# ✅ Fire 866 processed and saved to 'data'
# ✅ Fire 867 processed and saved to 'data'
# ✅ Fire 868 processed and saved to 'data'
# ✅ Fire 869 processed and saved to 'data'
# ✅ Fire 870 processed and saved to 'data'
# ✅ Fire 871 processed and saved to 'data'
# ✅ Fire 872 processed and saved to 'data'
# ✅ Fire 873 processed and saved to 'data'
# ✅ Fire 874 processed and saved to 'data'
# ✅ Fire 875 processed and saved to 'data'
# ✅ Fire 876 processed and saved to 'data'
# ✅ Fire 877 processed and saved to 'data'
# ✅ Fire 878 processed and saved to 'data'
# ✅ Fire 879 processed and saved to 'data'
# ✅ Fire 880 processed and saved to 'data'
# ✅ Fire 881 processed and saved to 'data'
# ✅ Fire 882 processed and saved to 'data'
# ✅ Fire 883 processed and saved to 'data'
# ✅ Fire 884 processed and saved to 'data'
# ✅ Fire 885 processed and saved to 'data'
# ✅ Fire 886 processed and saved to 'data'
# ✅ Fire 887 processed and saved to 'data'
# ✅ Fire 888 processed and saved to 'data'
# ✅ Fire 889 processed and saved to 'data'
# ✅ Fire 890 processed and saved to 'data'
# ✅ Fire 891 processed and saved to 'data'
# ✅ Fire 892 processed and saved to 'data'
# ✅ Fire 893 processed and saved to 'data'
# ✅ Fire 894 processed and saved to 'data'
# ✅ Fire 895 processed and saved to 'data'
# ✅ Fire 896 processed and saved to 'data'
# ✅ Fire 897 processed and saved to 'data'
# ✅ Fire 898 processed and saved to 'data'
# ✅ Fire 899 processed and saved to 'data'
# ✅ Fire 900 processed and saved to 'data'
# ✅ Fire 901 processed and saved to 'data'
# ✅ Fire 902 processed and saved to 'data'
# ✅ Fire 903 processed and saved to 'data'
# ✅ Fire 904 processed and saved to 'data'
# ✅ Fire 905 processed and saved to 'data'
# ✅ Fire 906 processed and saved to 'data'
# ✅ Fire 907 processed and saved to 'data'
# ✅ Fire 908 processed and saved to 'data'
# ✅ Fire 909 processed and saved to 'data'
# ✅ Fire 910 processed and saved to 'data'
# ✅ Fire 911 processed and saved to 'data'
# ✅ Fire 912 processed and saved to 'data'
# ✅ Fire 913 processed and saved to 'data'
# ✅ Fire 914 processed and saved to 'data'
# ✅ Fire 915 processed and saved to 'data'
# ✅ Fire 916 processed and saved to 'data'
# ✅ Fire 917 processed and saved to 'data'
# ✅ Fire 918 processed and saved to 'data'
# ✅ Fire 919 processed and saved to 'data'
# ✅ Fire 920 processed and saved to 'data'
# ✅ Fire 921 processed and saved to 'data'
# ✅ Fire 922 processed and saved to 'data'
# ✅ Fire 923 processed and saved to 'data'
# ✅ Fire 924 processed and saved to 'data'
# ✅ Fire 925 processed and saved to 'data'
# ✅ Fire 926 processed and saved to 'data'
# ✅ Fire 927 processed and saved to 'data'
# ✅ Fire 928 processed and saved to 'data'
# ✅ Fire 929 processed and saved to 'data'
# ✅ Fire 930 processed and saved to 'data'
# ✅ Fire 931 processed and saved to 'data'
# ✅ Fire 932 processed and saved to 'data'
# ✅ Fire 933 processed and saved to 'data'
# ✅ Fire 934 processed and saved to 'data'
